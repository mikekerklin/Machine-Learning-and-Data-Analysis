# %% [markdown]
# <a href="https://colab.research.google.com/github/mikekerklin/Machine-Learning-and-Data-Analysis/blob/main/Homework_5_exercise_15_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
load_iris = load_iris()

# %% [markdown]
# Create Range of K Values

# %%
k_values = range(1,11)

# %% [markdown]
# Calculate WCSS for Each K Value

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(load_iris.data)
    wcss.append(kmeans.inertia_)

# %% [markdown]
# Plot WCSS vs K Values

# %%
plt.plot(k_values, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
